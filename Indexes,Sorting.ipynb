# %%
import numpy as np

# %%
import pandas as pd

# %%
df_exams=pd.read_csv('StudentsPerformance.csv')

# %%
#creating non repeatitive vlues
new_index=np.arange(0,1000)

# %%
#shuffling the index

np.random.shuffle(new_index)

# %%
df_exams['new_index']=new_index3


df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exams.insert(1,'snew_index',index_new)
df_exams
# Out:
#      gender  snew_index race/ethnicity parental level of education  \
# 0    female         485        group B           bachelor's degree
# 1    female         532        group C                some college
# 2    female          13        group B             master's degree
# 3      male         667        group A          associate's degree
# 4      male         971        group C                some college
# ..      ...         ...            ...                         ...
# 995  female         188        group E             master's degree
# 996    male         530        group C                 high school
# 997  female         999        group C                 high school
# 998  female         301        group D                some college
# 999  female         901        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...

# %% [markdown]
# #  Set Index

# %%
#set new index as index
df_exams.set_index('new_index',inplace=True)

# %%
df_exams
# Out:
#            gender  snew_index race/ethnicity parental level of education  \
# new_index
# 485        female         485        group B           bachelor's degree
# 532        female         532        group C                some college
# 13         female          13        group B             master's degree
# 667          male         667        group A          associate's degree
# 971          male         971        group C                some college
# ...           ...         ...            ...                         ...
# 188        female         188        group E             master's degree
# 530          male         530        group C                 high school
# 999        female         999        group C                 high school
# 301        female         301        group D                some college
# 901        female         901        group D                some college
#
#                   lunch test preparation course  math score  reading score  \
# ...

# %% [markdown]
# ## Sort indexes

# %%
#Sort the index in ascending order

df_exams.sort_index()
# Out:
#            gender  snew_index race/ethnicity parental level of education  \
# new_index
# 0            male           0        group D          associate's degree
# 1            male           1        group C                some college
# 2          female           2        group C           bachelor's degree
# 3          female           3        group C                 high school
# 4          female           4        group C           bachelor's degree
# ...           ...         ...            ...                         ...
# 995          male         995        group D                some college
# 996          male         996        group A            some high school
# 997          male         997        group D          associate's degree
# 998          male         998        group B            some high school
# 999        female         999        group C                 high school
#
#                   lunch test preparation course  math score  reading score  \
# ...

# %%
#Sort the index in decending order

df_exams.sort_index(ascending=False)
# Out:
#            gender  snew_index race/ethnicity parental level of education  \
# new_index
# 999        female         999        group C                 high school
# 998          male         998        group B            some high school
# 997          male         997        group D          associate's degree
# 996          male         996        group A            some high school
# 995          male         995        group D                some college
# ...           ...         ...            ...                         ...
# 4          female           4        group C           bachelor's degree
# 3          female           3        group C                 high school
# 2          female           2        group C           bachelor's degree
# 1            male           1        group C                some college
# 0            male           0        group D          associate's degree
#
#                   lunch test preparation course  math score  reading score  \
# ...

# %%
df_exams.sort_index(inplace=True)
df_exams
# Out:
#            gender  snew_index race/ethnicity parental level of education  \
# new_index
# 0            male           0        group D          associate's degree
# 1            male           1        group C                some college
# 2          female           2        group C           bachelor's degree
# 3          female           3        group C                 high school
# 4          female           4        group C           bachelor's degree
# ...           ...         ...            ...                         ...
# 995          male         995        group D                some college
# 996          male         996        group A            some high school
# 997          male         997        group D          associate's degree
# 998          male         998        group B            some high school
# 999        female         999        group C                 high school
#
#                   lunch test preparation course  math score  reading score  \
# ...
